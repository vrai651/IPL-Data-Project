# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Read Data

# %%
matchdata = pd.read_csv('match_data.csv')
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_11312\1682755916.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   matchdata = pd.read_csv('match_data.csv')

# %%
matchinfodata = pd.read_csv('match_info_data.csv')

# %% [markdown]
# # Match Data

# %%
matchdata.head()
# Out:
#    match_id season  start_date                             venue  innings  \
# 0   1370353   2023  2023-05-29  Narendra Modi Stadium, Ahmedabad        1
# 1   1370353   2023  2023-05-29  Narendra Modi Stadium, Ahmedabad        1
# 2   1370353   2023  2023-05-29  Narendra Modi Stadium, Ahmedabad        1
# 3   1370353   2023  2023-05-29  Narendra Modi Stadium, Ahmedabad        1
# 4   1370353   2023  2023-05-29  Narendra Modi Stadium, Ahmedabad        1
#
#    ball    batting_team         bowling_team       striker   non_striker  ...  \
# 0   0.1  Gujarat Titans  Chennai Super Kings       WP Saha  Shubman Gill  ...
# 1   0.2  Gujarat Titans  Chennai Super Kings       WP Saha  Shubman Gill  ...
# 2   0.3  Gujarat Titans  Chennai Super Kings       WP Saha  Shubman Gill  ...
# 3   0.4  Gujarat Titans  Chennai Super Kings  Shubman Gill       WP Saha  ...
# 4   0.5  Gujarat Titans  Chennai Super Kings       WP Saha  Shubman Gill  ...
#
# ...

# %% [markdown]
# # Match Info Data

# %%
matchinfodata
# Out:
#            id   season        city        date                        team1  \
# 0     1370353     2023   Ahmedabad  2023/05/29               Gujarat Titans
# 1     1370352     2023   Ahmedabad  2023/05/26               Gujarat Titans
# 2     1370351     2023     Chennai  2023/05/24               Mumbai Indians
# 3     1370350     2023     Chennai  2023/05/23          Chennai Super Kings
# 4     1359543     2023      Mumbai  2023/05/21          Sunrisers Hyderabad
# ...       ...      ...         ...         ...                          ...
# 1019   335986  2007/08     Kolkata  2008/04/20        Kolkata Knight Riders
# 1020   335985  2007/08      Mumbai  2008/04/20               Mumbai Indians
# 1021   335984  2007/08       Delhi  2008/04/19             Delhi Daredevils
# 1022   335983  2007/08  Chandigarh  2008/04/19              Kings XI Punjab
# 1023   335982  2007/08   Bangalore  2008/04/18  Royal Challengers Bangalore
#
# ...

# %%
matchinfodata.head()
# Out:
#         id season       city        date                team1  \
# 0  1370353   2023  Ahmedabad  2023/05/29       Gujarat Titans
# 1  1370352   2023  Ahmedabad  2023/05/26       Gujarat Titans
# 2  1370351   2023    Chennai  2023/05/24       Mumbai Indians
# 3  1370350   2023    Chennai  2023/05/23  Chennai Super Kings
# 4  1359543   2023     Mumbai  2023/05/21  Sunrisers Hyderabad
#
#                   team2          toss_winner toss_decision  result  \
# 0   Chennai Super Kings  Chennai Super Kings         field     D/L
# 1        Mumbai Indians       Mumbai Indians         field  normal
# 2  Lucknow Super Giants       Mumbai Indians           bat  normal
# 3        Gujarat Titans       Gujarat Titans         field  normal
# 4        Mumbai Indians       Mumbai Indians         field  normal
#
#    dl_applied               winner  win_by_runs  win_by_wickets  \
# 0           1  Chennai Super Kings            0               5
# ...

# %% [markdown]
# # Chennai Super Kings (M. A. Chidambaram Stadium records)
# M. A. Chidambaram Stadium matchs

# %%
Chennai = matchinfodata[matchinfodata['city'] == 'Chennai']
Chennai
# Out:
#            id   season     city        date                team1  \
# 2     1370351     2023  Chennai  2023/05/24       Mumbai Indians
# 3     1370350     2023  Chennai  2023/05/23  Chennai Super Kings
# 14    1359535     2023  Chennai  2023/05/14  Chennai Super Kings
# 19    1359529     2023  Chennai  2023/05/10  Chennai Super Kings
# 25    1359523     2023  Chennai  2023/05/06       Mumbai Indians
# ...       ...      ...      ...         ...                  ...
# 993    336013  2007/08  Chennai  2008/05/10  Chennai Super Kings
# 998    336007  2007/08  Chennai  2008/05/06  Chennai Super Kings
# 1004   336001  2007/08  Chennai  2008/05/02  Chennai Super Kings
# 1013   335993  2007/08  Chennai  2008/04/26  Chennai Super Kings
# 1016   335989  2007/08  Chennai  2008/04/23  Chennai Super Kings
#
#                       team2            toss_winner toss_decision  result  \
# 2      Lucknow Super Giants         Mumbai Indians           bat  normal
# ...

# %% [markdown]
# #### M. A. Chidambaram Stadium matchs win

# %%
Chennaiwin = Chennai[Chennai['winner'] == 'Chennai Super Kings']
Chennaiwin
# Out:
#            id   season     city        date                        team1  \
# 3     1370350     2023  Chennai  2023/05/23          Chennai Super Kings
# 19    1359529     2023  Chennai  2023/05/10          Chennai Super Kings
# 25    1359523     2023  Chennai  2023/05/06               Mumbai Indians
# 45    1359503     2023  Chennai  2023/04/21          Sunrisers Hyderabad
# 68    1359480     2023  Chennai  2023/04/03          Chennai Super Kings
# 278   1178425     2019  Chennai  2019/05/01          Chennai Super Kings
# 287   1178416     2019  Chennai  2019/04/23          Sunrisers Hyderabad
# 305   1178398     2019  Chennai  2019/04/09        Kolkata Knight Riders
# 309   1178393     2019  Chennai  2019/04/06          Chennai Super Kings
# 317   1175367     2019  Chennai  2019/03/31          Chennai Super Kings
# 327   1175356     2019  Chennai  2019/03/23  Royal Challengers Bangalore
# 383   1136565     2018  Chennai  2018/04/10        Kolkata Knight Riders
# ...

# %% [markdown]
# #### M. A. Chidambaram Stadium matchs win count

# %%
Chennaiwincount = len(Chennaiwin)
Chennaiwincount
# Out:
# 45

# %% [markdown]
# ##### M. A. Chidambaram Stadium matchs lost

# %%
Chennailost = Chennai[Chennai['winner'] != 'Chennai Super Kings']
Chennailost
# Out:
#            id   season     city        date                        team1  \
# 2     1370351     2023  Chennai  2023/05/24               Mumbai Indians
# 14    1359535     2023  Chennai  2023/05/14          Chennai Super Kings
# 32    1359515     2023  Chennai  2023/04/30          Chennai Super Kings
# 57    1359491     2023  Chennai  2023/04/12             Rajasthan Royals
# 189   1254077     2021  Chennai  2021/04/25               Delhi Capitals
# 191   1254074     2021  Chennai  2021/04/23               Mumbai Indians
# 194   1254071     2021  Chennai  2021/04/21                 Punjab Kings
# 195   1254070     2021  Chennai  2021/04/20               Mumbai Indians
# 198   1254067     2021  Chennai  2021/04/18  Royal Challengers Bangalore
# 199   1254066     2021  Chennai  2021/04/17               Mumbai Indians
# 202   1254063     2021  Chennai  2021/04/14  Royal Challengers Bangalore
# 203   1254062     2021  Chennai  2021/04/13               Mumbai Indians
# ...

# %% [markdown]
# #### M. A. Chidambaram Stadium matchs lost count

# %%
Chennailostcount = len(Chennailost)
Chennailostcount
# Out:
# 31

# %% [markdown]
# ### summary of win and lost

# %%
print("Chennai Super Kings Wins in M. A. Chidambaram Stadium:", Chennaiwincount)
print("Chennai Super Kings Losses in M. A. Chidambaram Stadium:", Chennailostcount)
# Out:
# Chennai Super Kings Wins in M. A. Chidambaram Stadium: 45
# Chennai Super Kings Losses in M. A. Chidambaram Stadium: 31

# %% [markdown]
# #### Toss Decision Field

# %%
tossfield = Chennai[Chennai['toss_decision'] == 'field']
tossfield
# Out:
#            id   season     city        date                        team1  \
# 3     1370350     2023  Chennai  2023/05/23          Chennai Super Kings
# 25    1359523     2023  Chennai  2023/05/06               Mumbai Indians
# 45    1359503     2023  Chennai  2023/04/21          Sunrisers Hyderabad
# 57    1359491     2023  Chennai  2023/04/12             Rajasthan Royals
# 68    1359480     2023  Chennai  2023/04/03          Chennai Super Kings
# 191   1254074     2021  Chennai  2021/04/23               Mumbai Indians
# 202   1254063     2021  Chennai  2021/04/14  Royal Challengers Bangalore
# 203   1254062     2021  Chennai  2021/04/13               Mumbai Indians
# 205   1254060     2021  Chennai  2021/04/11        Kolkata Knight Riders
# 207   1254058     2021  Chennai  2021/04/09               Mumbai Indians
# 278   1178425     2019  Chennai  2019/05/01          Chennai Super Kings
# 284   1178419     2019  Chennai  2019/04/26               Mumbai Indians
# ...

# %% [markdown]
# #### Count of Toss Decision Field

# %%
tossfieldcount = len(tossfield)
tossfieldcount
# Out:
# 31

# %% [markdown]
# #### Toss Decision Bat

# %%
tossbat = Chennai[Chennai['toss_decision'] == 'bat']
tossbat
# Out:
#            id   season     city        date                        team1  \
# 2     1370351     2023  Chennai  2023/05/24               Mumbai Indians
# 14    1359535     2023  Chennai  2023/05/14          Chennai Super Kings
# 19    1359529     2023  Chennai  2023/05/10          Chennai Super Kings
# 32    1359515     2023  Chennai  2023/04/30          Chennai Super Kings
# 189   1254077     2021  Chennai  2021/04/25               Delhi Capitals
# 194   1254071     2021  Chennai  2021/04/21                 Punjab Kings
# 195   1254070     2021  Chennai  2021/04/20               Mumbai Indians
# 198   1254067     2021  Chennai  2021/04/18  Royal Challengers Bangalore
# 199   1254066     2021  Chennai  2021/04/17               Mumbai Indians
# 271   1181764     2019  Chennai  2019/05/07          Chennai Super Kings
# 309   1178393     2019  Chennai  2019/04/06          Chennai Super Kings
# 521    829797     2015  Chennai  2015/05/10          Chennai Super Kings
# ...

# %% [markdown]
# #### count of Toss Decision Bat

# %%
tossbatcount = len(tossbat)
tossbatcount
# Out:
# 45

# %% [markdown]
# ### summary of toss

# %%
print("Matches where Chennai Super Kings chose to field:", tossfieldcount)
print("Matches where Chennai Super Kings chose to bat:", tossbatcount)
# Out:
# Matches where Chennai Super Kings chose to field: 31
# Matches where Chennai Super Kings chose to bat: 45

# %% [markdown]
# #### Toss Decision field Win

# %%
tossfieldwin = Chennai[(Chennai['toss_decision'] == 'field') & (Chennai['winner'] == 'Chennai Super Kings')]
print(tossfieldwin)
# Out:
#            id   season     city        date                        team1  \
# 3     1370350     2023  Chennai  2023/05/23          Chennai Super Kings
# 25    1359523     2023  Chennai  2023/05/06               Mumbai Indians
# 45    1359503     2023  Chennai  2023/04/21          Sunrisers Hyderabad
# 68    1359480     2023  Chennai  2023/04/03          Chennai Super Kings
# 278   1178425     2019  Chennai  2019/05/01          Chennai Super Kings
# 287   1178416     2019  Chennai  2019/04/23          Sunrisers Hyderabad
# 305   1178398     2019  Chennai  2019/04/09        Kolkata Knight Riders
# 317   1175367     2019  Chennai  2019/03/31          Chennai Super Kings
# 327   1175356     2019  Chennai  2019/03/23  Royal Challengers Bangalore
# 383   1136565     2018  Chennai  2018/04/10        Kolkata Knight Riders
# 539    829765     2015  Chennai  2015/04/28          Chennai Super Kings
# 564    829707     2015  Chennai  2015/04/09          Chennai Super Kings
# ...

# %% [markdown]
# #### Count of Toss Decision field Win

# %%
tossfieldwincount = len(tossfieldwin)
tossfieldwincount
# Out:
# 20

# %% [markdown]
# ### Toss Decision field Loss

# %%
tossfieldlost = Chennai[(Chennai['toss_decision'] == 'field') & (Chennai['winner'] != 'Chennai Super Kings')]
tossfieldlost
# Out:
#           id   season     city        date                        team1  \
# 57   1359491     2023  Chennai  2023/04/12             Rajasthan Royals
# 191  1254074     2021  Chennai  2021/04/23               Mumbai Indians
# 202  1254063     2021  Chennai  2021/04/14  Royal Challengers Bangalore
# 203  1254062     2021  Chennai  2021/04/13               Mumbai Indians
# 205  1254060     2021  Chennai  2021/04/11        Kolkata Knight Riders
# 207  1254058     2021  Chennai  2021/04/09               Mumbai Indians
# 284  1178419     2019  Chennai  2019/04/26               Mumbai Indians
# 775   548306     2012  Chennai  2012/04/04          Chennai Super Kings
# 777   501270     2011  Chennai  2011/05/27  Royal Challengers Bangalore
# 893   419121  2009/10  Chennai  2010/03/21          Chennai Super Kings
# 998   336007  2007/08  Chennai  2008/05/06          Chennai Super Kings
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# #### count of Toss Decision field Loss

# %%
tossfieldlostcount = len(tossfieldlost)
tossfieldlostcount
# Out:
# 11

# %% [markdown]
# ### Toss Decision bat Win

# %%
tossbatwin = Chennai[(Chennai['toss_decision'] == 'bat') & (Chennai['winner'] == 'Chennai Super Kings')]
print(tossbatwin)
# Out:
#            id   season     city        date                team1  \
# 19    1359529     2023  Chennai  2023/05/10  Chennai Super Kings
# 309   1178393     2019  Chennai  2019/04/06  Chennai Super Kings
# 521    829797     2015  Chennai  2015/05/10  Chennai Super Kings
# 529    829779     2015  Chennai  2015/05/04  Chennai Super Kings
# 542    829753     2015  Chennai  2015/04/25  Chennai Super Kings
# 562    829711     2015  Chennai  2015/04/11  Chennai Super Kings
# 638    598062     2013  Chennai  2013/05/14  Chennai Super Kings
# 657    598041     2013  Chennai  2013/05/02  Chennai Super Kings
# 668    598030     2013  Chennai  2013/04/25  Chennai Super Kings
# 672    598026     2013  Chennai  2013/04/22  Chennai Super Kings
# 732    548352     2012  Chennai  2012/05/04  Chennai Super Kings
# 749    548332     2012  Chennai  2012/04/21  Chennai Super Kings
# 763    548318     2012  Chennai  2012/04/12  Chennai Super Kings
# ...

# %% [markdown]
# #### Count of Toss Decision field Win

# %%
tossbatwincount = len(tossbatwin)
tossbatwincount
# Out:
# 25

# %% [markdown]
# #### Toss Decision field Loss

# %%
tossbatlost = Chennai[(Chennai['toss_decision'] == 'bat') & (Chennai['winner'] != 'Chennai Super Kings')]
tossbatlost
# Out:
#            id   season     city        date                        team1  \
# 2     1370351     2023  Chennai  2023/05/24               Mumbai Indians
# 14    1359535     2023  Chennai  2023/05/14          Chennai Super Kings
# 32    1359515     2023  Chennai  2023/04/30          Chennai Super Kings
# 189   1254077     2021  Chennai  2021/04/25               Delhi Capitals
# 194   1254071     2021  Chennai  2021/04/21                 Punjab Kings
# 195   1254070     2021  Chennai  2021/04/20               Mumbai Indians
# 198   1254067     2021  Chennai  2021/04/18  Royal Challengers Bangalore
# 199   1254066     2021  Chennai  2021/04/17               Mumbai Indians
# 271   1181764     2019  Chennai  2019/05/07          Chennai Super Kings
# 524    829789     2015  Chennai  2015/05/08          Chennai Super Kings
# 683    598015     2013  Chennai  2013/04/15          Chennai Super Kings
# 697    598002     2013  Chennai  2013/04/06          Chennai Super Kings
# ...

# %% [markdown]
# #### count of Toss Decision field Loss

# %%
tossbatlostcount = len(tossbatlost)
tossbatlostcount
# Out:
# 20

# %%
print("Toss Decision: Bat | Match Win Count:", tossbatwincount)
print("Toss Decision: Bat | Match Lost Count:", tossbatlostcount)
print("Toss Decision: Field | Match Win Count:", tossfieldwincount)
print("Toss Decision: Field | Match Lost Count:", tossfieldlostcount)
print("Total Match CSK Win Count:", Chennaiwincount)
print("CTotal Match CSK Lost Count:", Chennailostcount)
# Out:
# Toss Decision: Bat | Match Win Count: 25
# Toss Decision: Bat | Match Lost Count: 20
# Toss Decision: Field | Match Win Count: 20
# Toss Decision: Field | Match Lost Count: 11
# Total Match CSK Win Count: 45
# CTotal Match CSK Lost Count: 31

# %% [markdown]
# ### Average number of matches won by CSK in Chennai

# %%
total_matches = len(Chennai)
total_wins = len(Chennai[Chennai['winner'] == 'Chennai Super Kings'])
average_win = total_wins / total_matches

print("Average number of matches won by Chennai Super Kings  in Chennai:", average_win)
# Out:
# Average number of matches won by Chennai Super Kings  in Chennai: 0.5921052631578947

# %% [markdown]
# ### Average number of matches lost by CSK in Chennai

# %%
total_matches = len(Chennai)
total_losses = len(Chennai[Chennai['winner'] != 'Chennai Super Kings'])

average_loss = total_losses / total_matches

print("Average number of matches lost by Chennai Super Kings  in Chennai:", average_loss)
# Out:
# Average number of matches lost by Chennai Super Kings  in Chennai: 0.40789473684210525

# %% [markdown]
# # List of all cities

# %%
unique_cities = matchinfodata['city'].unique()
print("List of all cities:", unique_cities)
# Out:
# List of all cities: ['Ahmedabad' 'Chennai' 'Mumbai' 'Bengaluru' 'Kolkata' 'Delhi' 'Dharamsala'
#  'Hyderabad' 'Lucknow' 'Jaipur' 'Chandigarh' 'Guwahati' 'Navi Mumbai'
#  'Pune' 'Dubai' 'Sharjah' 'Abu Dhabi' nan 'Visakhapatnam' 'Indore'
#  'Bangalore' 'Kanpur' 'Rajkot' 'Raipur' 'Ranchi' 'Cuttack' 'Kochi'
#  'Nagpur' 'Johannesburg' 'Centurion' 'Durban' 'Bloemfontein'
#  'Port Elizabeth' 'Kimberley' 'East London' 'Cape Town']

# %% [markdown]
# ## Total number of matches played in different cities

# %%
city_match_count = matchinfodata['city'].value_counts().reset_index()
city_match_count.columns = ['City', 'Total Matches']

print("Total Matches played in each city:")
print(city_match_count)
# Out:
# Total Matches played in each city:
#               City  Total Matches
# 0           Mumbai            166
# 1          Kolkata             86
# 2            Delhi             85
# 3          Chennai             76
# 4        Hyderabad             71
# 5        Bangalore             65
# 6       Chandigarh             61
# 7           Jaipur             52
# 8             Pune             51
# 9        Abu Dhabi             37
# 10       Ahmedabad             28
# 11       Bengaluru             22
# 12          Durban             15
# 13           Dubai             13
# 14   Visakhapatnam             13
# 15       Centurion             12
# 16      Dharamsala             11
# 17         Sharjah             10
# 18          Rajkot             10
# 19          Indore              9
# 20     Navi Mumbai              9
# 21    Johannesburg              8
# 22         Cuttack              7
# 23  Port Elizabeth              7
# 24       Cape Town              7
# ...

# %% [markdown]
# # Chennai Super Kings (Mumbai Stadium records)

# %%
Mumbai = matchinfodata[matchinfodata['city'] == 'Mumbai']
Mumbai
# Out:
#            id   season    city        date                        team1  \
# 4     1359543     2023  Mumbai  2023/05/21          Sunrisers Hyderabad
# 17    1359531     2023  Mumbai  2023/05/12               Mumbai Indians
# 20    1359528     2023  Mumbai  2023/05/09  Royal Challengers Bangalore
# 33    1359516     2023  Mumbai  2023/04/30             Rajasthan Royals
# 43    1359505     2023  Mumbai  2023/04/22                 Punjab Kings
# ...       ...      ...     ...         ...                          ...
# 988    336018  2007/08  Mumbai  2008/05/14               Mumbai Indians
# 997    336008  2007/08  Mumbai  2008/05/07               Mumbai Indians
# 1000   336004  2007/08  Mumbai  2008/05/04               Mumbai Indians
# 1010   335994  2007/08  Mumbai  2008/04/27               Mumbai Indians
# 1020   335985  2007/08  Mumbai  2008/04/20               Mumbai Indians
#
#                             team2       toss_winner toss_decision  result  \
# ...

# %% [markdown]
# ### Mumbai Stadium matchs win

# %%
Mumbaiwin = Mumbai[Mumbai['winner'] == 'Chennai Super Kings']
Mumbaiwin
# Out:
#           id   season    city        date                        team1  \
# 62   1359486     2023  Mumbai  2023/04/08               Mumbai Indians
# 126  1304068     2022  Mumbai  2022/04/12          Chennai Super Kings
# 188  1254076     2021  Mumbai  2021/04/25          Chennai Super Kings
# 193  1254072     2021  Mumbai  2021/04/21          Chennai Super Kings
# 196  1254069     2021  Mumbai  2021/04/19          Chennai Super Kings
# 200  1254065     2021  Mumbai  2021/04/16                 Punjab Kings
# 328  1136620     2018  Mumbai  2018/05/27          Sunrisers Hyderabad
# 331  1136617     2018  Mumbai  2018/05/22          Sunrisers Hyderabad
# 387  1136561     2018  Mumbai  2018/04/07               Mumbai Indians
# 554   829729     2015  Mumbai  2015/04/17               Mumbai Indians
# 568   734045     2014  Mumbai  2014/05/28          Chennai Super Kings
# 593   733995     2014  Mumbai  2014/05/10               Mumbai Indians
# ...

# %% [markdown]
# ### Mumbai Stadium matchs win count

# %%
Mumbaiwincount = len(Mumbaiwin)
Mumbaiwincount
# Out:
# 17

# %% [markdown]
# ### Mumbai Stadium matches lost

# %%
Mumbailost = Mumbai[Mumbai['winner'] != 'Chennai Super Kings']
Mumbailost
# Out:
#            id   season    city        date                        team1  \
# 4     1359543     2023  Mumbai  2023/05/21          Sunrisers Hyderabad
# 17    1359531     2023  Mumbai  2023/05/12               Mumbai Indians
# 20    1359528     2023  Mumbai  2023/05/09  Royal Challengers Bangalore
# 33    1359516     2023  Mumbai  2023/04/30             Rajasthan Royals
# 43    1359505     2023  Mumbai  2023/04/22                 Punjab Kings
# ...       ...      ...     ...         ...                          ...
# 988    336018  2007/08  Mumbai  2008/05/14               Mumbai Indians
# 997    336008  2007/08  Mumbai  2008/05/07               Mumbai Indians
# 1000   336004  2007/08  Mumbai  2008/05/04               Mumbai Indians
# 1010   335994  2007/08  Mumbai  2008/04/27               Mumbai Indians
# 1020   335985  2007/08  Mumbai  2008/04/20               Mumbai Indians
#
#                             team2       toss_winner toss_decision  result  \
# ...

# %% [markdown]
# ### Mumbai Stadium matches lost count

# %%
Mumbailostcount = len(Mumbailost)
Mumbailostcount
# Out:
# 149

# %% [markdown]
# ## summary of win and lost in Mumbai Stadium

# %%
print("Chennai Super Kings Wins in Mumbai Stadium:", Mumbaiwincount)
print("Chennai Super Kings Losses in Mumbai Stadium:", Mumbailostcount)
# Out:
# Chennai Super Kings Wins in Mumbai Stadium: 17
# Chennai Super Kings Losses in Mumbai Stadium: 149
